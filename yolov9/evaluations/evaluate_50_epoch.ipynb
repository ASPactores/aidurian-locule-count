# %%
import pandas as pd
from ultralytics import YOLO
import os
from evaluations.utils.plot import plot_precision_recall_curve

HOME = os.getcwd()

DATASET_DIRECTORY = f"{HOME}/datasets/data.yaml"

# %%
model = YOLO(f"{HOME}/weights/epoch50.pt")

metrics = model.val(
    data=DATASET_DIRECTORY,
    save_json=True,
    split="test",
    name="epoch_50"
)

iou_score = metrics
p = metrics.seg.p
r = metrics.seg.r

# Create a DataFrame with metrics
df = pd.DataFrame(
    columns=["Precision", "Recall", "AP 50", "AP 75", "AP 50:95"],
    data=[[p[0], r[0], metrics.seg.map50, metrics.seg.map75, metrics.seg.map]],
)

df
# Out:
# Ultralytics 8.3.73 🚀 Python-3.11.10 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLOv9c-seg summary (fused): 411 layers, 27,625,299 parameters, 0 gradients, 157.6 GFLOPs
# val: Scanning /app/datasets/test/labels.cache... 29 images, 0 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:53<00:00, 26.72s/it]
#                    all         29        139      0.958      0.978       0.99      0.845      0.951       0.97      0.976       0.84
# Speed: 10.7ms preprocess, 1661.1ms inference, 0.0ms loss, 17.9ms postprocess per image
# Saving /ultralytics/runs/segment/epoch_504/predictions.json...
# Results saved to /ultralytics/runs/segment/epoch_504
#    Precision    Recall    AP 50     AP 75  AP 50:95
# 0   0.950666  0.970431  0.97591  0.955216   0.84005

# %%
# %matplotlib inline
plot_precision_recall_curve(metrics, "50 Epochs")
